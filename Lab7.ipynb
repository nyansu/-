# %%
import cv2
from google.colab.patches import cv2_imshow
# Загрузка изображений
img = cv2.imread('img.jpg')
template = cv2.imread('pttrn.png')

# Нахождение шаблона на изображении
result = cv2.matchTemplate(img, template, cv2.TM_CCOEFF_NORMED)

# Установка порога для определения совпадений
threshold = 0.7
locations = np.where(result >= threshold)
locations = list(zip(*locations[::-1]))

# Рисование прямоугольника вокруг найденного шаблона
for loc in locations:
    cv2.rectangle(img, loc, (loc[0] + template.shape[1], loc[1] + template.shape[0]), (0, 0, 0), 3)

# Вывод изображений
cv2_imshow(template)
cv2_imshow(img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=35x57>
# <PIL.Image.Image image mode=RGB size=1280x1280>
